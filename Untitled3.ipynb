# %% [markdown]
# <a href="https://colab.research.google.com/github/neevj0711-hue/signature/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

zip_file_path = "/content/drive/MyDrive/rugwed neev signature presence.v3i.yolov8.zip"
destination_path = "/content/dataset"

# Ensure the destination directory exists
os.makedirs(destination_path, exist_ok=True)

# Copy the zip file to a local path before unzipping
# !cp "{zip_file_path}" "/content/temp_dataset.zip"

# Unzip the file from the local path
# !unzip -o "/content/temp_dataset.zip" -d "{destination_path}"

print(f"Successfully unzipped to {destination_path}")
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/test/labels/ixp01f00_1_png.rf.29149e4aa8e939c8fb10d4e00d986b85.txt
#   inflating: /content/dataset/test/labels/text_nosig_0343_jpg.rf.8efe850934b5449304b4d2fcfb3b70ba.txt
#   inflating: /content/dataset/test/labels/text_nosig_0474_jpg.rf.86ca4490d44325f13eea650d62e5519e.txt
#   inflating: /content/dataset/test/labels/text_nosig_0667_jpg.rf.ff16a719b264823582b620b8108b04d1.txt
#   inflating: /content/dataset/test/labels/ztz52d00-page02_2_png.rf.baead6cfb0ebc42503804d4ef5b54446.txt
#   inflating: /content/dataset/test/labels/text_nosig_0387_jpg.rf.a3f1d5165f32626e3850c8b643f18fd0.txt
#   inflating: /content/dataset/test/labels/text_nosig_0519_jpg.rf.e7ee5ec3722f60467972319e0051b5d3.txt
#   inflating: /content/dataset/test/labels/izj51a00_png.rf.94dfdfa32088061d3a3425b84910ea77.txt
#   inflating: /content/dataset/test/labels/text_nosig_0692_jpg.rf.06d77a66479474b392c23b1b24cb3101.txt
# ...

# %%
# !cat /content/dataset/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 1
# names: ['signature']
#
# roboflow:
#   workspace: rugwed
#   project: rugwed-neev-signature-presence
#   version: 3
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/rugwed/rugwed-neev-signature-presence/dataset/3

# %%
import yaml
with open('/content/dataset/data.yaml', 'r') as f:
    data = yaml.safe_load(f)
data['path'] = '/content/dataset'
data['train'] = 'train/images'
data['val'] = 'valid/images'
data['test'] = 'test/images'
with open('/content/dataset/data.yaml', 'w') as f:
    yaml.dump(data, f)
print("✅ Done")
# Out:
# ✅ Done

# %%
# !pip install ultralytics -q

from ultralytics import YOLO

model = YOLO('yolov8n.pt')

model.train(
    data='/content/dataset/data.yaml',
    epochs=50,
    imgsz=640,
    batch=16,
    name='signature_model'
)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.5 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.48 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import time
while True:
    time.sleep(55)
    print("Still alive! ⏰")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6195/3971264974.py in <cell line: 0>()
#       1 import time
#       2 while True:
# ----> 3     time.sleep(55)
#       4     print("Still alive! ⏰")
#
# KeyboardInterrupt:

# %%
# %%javascript
# function ClickConnect(){
#     console.log("Keeping Colab alive...");
#     document.querySelector("colab-toolbar-button#connect").click()
# }
# setInterval(ClickConnect, 60000)

# %%
from google.colab import files
files.download('/content/runs/detect/signature_model/weights/best.pt')

# %%
# !cp /content/runs/detect/signature_model/weights/best.pt "/content/drive/MyDrive/best.pt"
print("✅ Saved to Google Drive!")
# Out:
# ✅ Saved to Google Drive!

# %%
from ultralytics import YOLO

model = YOLO('/content/runs/detect/signature_model/weights/best.pt')

# Export to TFLite (for mobile)
model.export(format='tflite')

# This creates best.tflite file
# Out:
# Ultralytics 8.4.48 🚀 Python-3.12.13 torch-2.10.0+cu128 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/runs/detect/signature_model/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (6.0 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<2.0.0', 'onnxslim>=0.1.71', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 12 packages in 301ms
# Prepared 4 packages in 6.40s
# Installed 4 packages in 296ms
#  + colorama==0.4.6
#  + onnx==1.21.0
#  + onnxruntime-gpu==1.26.0
#  + onnxslim==0.1.93
#
# requirements: AutoUpdate success ✅ 7.6s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ...

# %%
from google.colab import files
files.download('/content/dataset/data.yaml')
